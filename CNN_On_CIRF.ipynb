# %% [markdown]
# # CNN on CIFAR -10

# %% [markdown]
# in this repo i am going to apply an cnn on cirf dataset

# %% [markdown]
# lets import all the necesarry libraries for the program

# %%
import torch  # pytorch main library
from torch import nn # neural network module

import torchvision # computer vision library
from torchvision import datasets # datasets module

import matplotlib.pyplot as plt  # plotting library

# %%
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available():
    device = "mps"
else:
    device = "cpu"

device
# Out:
# 'cpu'

# %% [markdown]
# ## Download the dataset

# %%
train_data = datasets.CIFAR10(
    root="data", # directory to store the data
    train=True,  # use training set
    download=True, # download if not present
    transform= torchvision.transforms.ToTensor(), # transform to tensor
    target_transform=None, # no target transform 
)

test_data = datasets.CIFAR10(
    root="data", # directory to store the data      
    train=False,  # use test set
    download=True, # download if not present
    transform= torchvision.transforms.ToTensor(), # transform to tensor
    target_transform=None, 
)# no target transform
# Out:
# 2.2%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train_data = datasets.CIFAR10(
#       2     root="data", # directory to store the data
#       3     train=True,  # use training set
#       4     download=True, # download if not present
#       5     transform= torchvision.transforms.ToTensor(), # transform to tensor
#       6     target_transform=None, # no target transform
#       7 )
#       9 test_data = datasets.CIFAR10(
#      10     root="data", # directory to store the data
#      11     train=False,  # use test set
#    (...)     14     target_transform=None,
#      15 )# no target transform
#
# File c:\PyTorch\.venv\Lib\site-packages\torchvision\datasets\cifar.py:66, in CIFAR10.__init__(self, root, train, transform, target_transform, download)
#      63 self.train = train  # training set or test set
#      65 if download:
# ...
